# %% [markdown]
# **Justin Hovious**
#
# **5/2/2026**
#
# **Initial Model Selection Using LazyPredict**

# %%
pip install lazypredict
# Out:
# Requirement already satisfied: lazypredict in /usr/local/lib/python3.12/dist-packages (0.3.0)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from lazypredict) (8.3.3)
# Requirement already satisfied: scikit-learn>=1.0 in /usr/local/lib/python3.12/dist-packages (from lazypredict) (1.6.1)
# Requirement already satisfied: pandas>=1.3 in /usr/local/lib/python3.12/dist-packages (from lazypredict) (2.2.2)
# Requirement already satisfied: tqdm>=4.0 in /usr/local/lib/python3.12/dist-packages (from lazypredict) (4.67.3)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.12/dist-packages (from lazypredict) (1.5.3)
# Requirement already satisfied: numpy>=1.21 in /usr/local/lib/python3.12/dist-packages (from lazypredict) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.3->lazypredict) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.3->lazypredict) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.3->lazypredict) (2026.1)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.0->lazypredict) (1.16.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.0->lazypredict) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.3->lazypredict) (1.17.0)

# %%
import pandas as pd
import numpy as np

from lazypredict.Supervised import LazyRegressor

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data = pd.read_csv("/content/drive/MyDrive/Machine Learning/CSCI 460/Large-scale Wave Energy Farm/WEC_Perth_49.csv")
df = pd.DataFrame(data)

# %%
print(df.shape)
# Out:
# (36043, 149)

# %%
# Removing XY coordinate columns since they aren't useful for prediction
df = df.drop(columns=[col for col in df.columns if col.startswith(('X', 'Y'))])
print(df.shape)
# Out:
# (36043, 51)

# %%
# Features and target
df_small = df.sample(n=5000, random_state=42)
X_small = df_small.drop(columns=['Total_Power'])
y_small = df_small['Total_Power']


# Split
X_train, X_test, y_train, y_test = train_test_split(
    X_small, y_small, test_size=0.2, random_state=42
)

# Run LazyRegressor
reg = LazyRegressor(verbose=0, ignore_warnings=True, custom_metric=None)
models, predictions = reg.fit(X_train, X_test, y_train, y_test)

print(models)
# Out:
#                                Adjusted R-Squared    R-Squared          RMSE  \
# Model
# LinearRegression                         0.999987     0.999988  4.218494e+02
# LassoLarsIC                              0.999987     0.999988  4.218494e+02
# RANSACRegressor                          0.999987     0.999988  4.218494e+02
# TransformedTargetRegressor               0.999987     0.999988  4.218494e+02
# BayesianRidge                            0.999987     0.999988  4.218509e+02
# LassoLarsCV                              0.999987     0.999988  4.218534e+02
# RidgeCV                                  0.999987     0.999988  4.220988e+02
# Lasso                                    0.999987     0.999988  4.224836e+02
# LassoLars                                0.999987     0.999988  4.231789e+02
# Ridge                                    0.999986     0.999987  4.374813e+02
# SGDRegressor                             0.999986     0.999987  4.459575e+02
# HuberRegressor                           0.999970     0.999971  6.524349e+02
# PoissonRegressor                         0.999775     0.999786  1.784918e+03
# Lars                                     0.999524     0.999548  2.593352e+03
# LarsCV                                   0.999524     0.999548  2.593352e+03
# LassoCV                                  0.998998     0.999049  3.761648e+03
# PassiveAggressiveRegressor               0.998977     0.999028  3.802650e+03
# ExtraTreesRegressor                      0.995804     0.996014  7.699138e+03
# RandomForestRegressor                    0.995482     0.995708  7.989760e+03
# LGBMRegressor                            0.995044     0.995292  8.367553e+03
# HistGradientBoostingRegressor            0.995018     0.995268  8.389569e+03
# BaggingRegressor                         0.994997     0.995247  8.407481e+03
# XGBRegressor                             0.994857     0.995115  8.524127e+03
# DecisionTreeRegressor                    0.992634     0.993002  1.020168e+04
# ExtraTreeRegressor                       0.992093     0.992488  1.056964e+04
# GradientBoostingRegressor                0.992030     0.992429  1.061167e+04
# OrthogonalMatchingPursuit                0.985733     0.986447  1.419775e+04
# OrthogonalMatchingPursuitCV              0.985733     0.986447  1.419775e+04
# AdaBoostRegressor                        0.983999     0.984800  1.503560e+04
# ElasticNet                               0.977274     0.978411  1.791884e+04
# GammaRegressor                           0.941275     0.944214  2.880426e+04
# TweedieRegressor                         0.940703     0.943671  2.894419e+04
# KNeighborsRegressor                      0.915062     0.919313  3.464151e+04
# ElasticNetCV                             0.023521     0.072394  1.174567e+05
# DummyRegressor                          -0.052707    -0.000019  1.219551e+05
# SVR                                     -0.054610    -0.001826  1.220653e+05
# QuantileRegressor                       -0.056622    -0.003738  1.221817e+05
# NuSVR                                   -0.070318    -0.016748  1.229710e+05
# GaussianProcessRegressor              -307.247275  -291.819484  2.086873e+06
# MLPRegressor                         -1088.029643 -1033.523654  3.922529e+06
# LinearSVR                            -1095.690558 -1040.801141  3.936302e+06
# KernelRidge                          -1096.579124 -1041.645234  3.937896e+06
#
#                                Time Taken
# Model
# LinearRegression                 0.034248
# LassoLarsIC                      0.054602
# RANSACRegressor                  0.071631
# TransformedTargetRegressor       0.188695
# BayesianRidge                    0.036143
# LassoLarsCV                      0.127807
# RidgeCV                          0.473201
# Lasso                            0.098195
# LassoLars                        0.043037
# Ridge                            0.021749
# SGDRegressor                     0.435287
# HuberRegressor                   0.298746
# PoissonRegressor                 0.050197
# Lars                             0.037293
# LarsCV                           0.122819
# LassoCV                          0.288675
# PassiveAggressiveRegressor       1.110752
# ExtraTreesRegressor              5.850750
# RandomForestRegressor           18.872347
# LGBMRegressor                    0.829011
# HistGradientBoostingRegressor    0.868752
# BaggingRegressor                 2.871471
# XGBRegressor                     3.493228
# DecisionTreeRegressor            0.406580
# ExtraTreeRegressor               0.142078
# GradientBoostingRegressor       10.987880
# OrthogonalMatchingPursuit        0.022530
# OrthogonalMatchingPursuitCV      0.049490
# AdaBoostRegressor                2.270796
# ElasticNet                       0.033403
# GammaRegressor                   0.025020
# TweedieRegressor                 0.088548
# KNeighborsRegressor              0.084631
# ElasticNetCV                     0.577562
# DummyRegressor                   0.023767
# SVR                              2.068076
# QuantileRegressor                1.030441
# NuSVR                            0.819673
# GaussianProcessRegressor         6.298358
# MLPRegressor                     9.507273
# LinearSVR                        0.029608
# KernelRidge                      1.366903
